# %%
import pandas as pd
from sklearn.svm import OneClassSVM
import matplotlib.pyplot as plt
from numpy import where
import numpy as np

# %%
df = pd.read_csv("../dataset/DATA_FINAL.csv")
# Out:
# C:\Users\A2IN\AppData\Local\Temp\ipykernel_11032\3358253211.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../dataset/DATA_FINAL.csv")

# %%
df
# Out:
#         RESP  ABPmean  ABPsys  ABPdias  Tblood   SpO2     HR  PULSE  ALARM
# 0       15.0     89.0   114.0     78.0    37.1  100.0  101.0  100.0  False
# 1       15.0     89.0   114.0     78.0    37.1  100.0  101.0  101.0  False
# 2       15.0     89.0   113.0     78.0    37.1  100.0  101.0  101.0  False
# 3       15.0     89.0   113.0     78.0    37.1  100.0  101.0  101.0  False
# 4       15.0     89.0   114.0     78.0    37.1  100.0  101.0  101.0  False
# ...      ...      ...     ...      ...     ...    ...    ...    ...    ...
# 131244  23.0    111.0   132.0     99.0    37.0   98.0  109.0  108.0  False
# 131245  23.0    111.0   132.0    100.0    37.0   98.0  109.0  108.0  False
# 131246  23.0    111.0   132.0    100.0    37.0   98.0  109.0  108.0  False
# 131247  23.0    112.0   133.0    101.0    37.0   98.0  109.0  108.0  False
# 131248  23.0    112.0   133.0    101.0    37.0   98.0  109.0  109.0  False
#
# [131249 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

# %%
ig = plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')


x = df["SpO2"]
y = df["ABPmean"]
z = df["Tblood"]

ax.scatter(x,y,z)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8, 30))
ax = plt.axes(projection='3d')

print(len(df))
for val in [True,False]:
    x = []
    y = []
    z = []
    for i in range(len(df)):
        if df.loc[i,"ALARM"] == val:
            y.append(df.loc[i,"ABPmean"])
            x.append(df.loc[i,"RESP"])
            z.append(df.loc[i,"SpO2"])
    if val == False:
        ax.scatter(x,y,z, c = "red")
        print(len(x))
    

plt.show()
# Out:
# 131249
# 126370

# %%
print(set(col))
# Out:
# {0, 100}

# %%
df
# Out:
#         RESP  ABPmean  ABPsys  ABPdias  Tblood   SpO2     HR  PULSE  ALARM
# 0       15.0     89.0   114.0     78.0    37.1  100.0  101.0  100.0  False
# 1       15.0     89.0   114.0     78.0    37.1  100.0  101.0  101.0  False
# 2       15.0     89.0   113.0     78.0    37.1  100.0  101.0  101.0  False
# 3       15.0     89.0   113.0     78.0    37.1  100.0  101.0  101.0  False
# 4       15.0     89.0   114.0     78.0    37.1  100.0  101.0  101.0  False
# ...      ...      ...     ...      ...     ...    ...    ...    ...    ...
# 131244  23.0    111.0   132.0     99.0    37.0   98.0  109.0  108.0  False
# 131245  23.0    111.0   132.0    100.0    37.0   98.0  109.0  108.0  False
# 131246  23.0    111.0   132.0    100.0    37.0   98.0  109.0  108.0  False
# 131247  23.0    112.0   133.0    101.0    37.0   98.0  109.0  108.0  False
# 131248  23.0    112.0   133.0    101.0    37.0   98.0  109.0  109.0  False
#
# [131249 rows x 9 columns]

# %%
cou = 0
for i in range(len(df["ALARM"])):
    if df.loc[i,"ALARM"] == True:
        cou +=1
    
print(cou)
# Out:
# 4263

# %%
cou = 0
for i in range(len(df["ALARM"])): 
    
    print(df.loc[i,"ALARM"])
    cou +=1
print(cou)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
print(df["A"]+1)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 131244    1
# 131245    1
# 131246    1
# 131247    1
# 131248    1
# Name: A, Length: 131249, dtype: object
